# %% [markdown]
# # 1632562 Activity 4

# %% [markdown]
# # **Heart Failure Patient Records**
# Table of Contents:
# * [About the Data](#data)
# * [Import Libraries](#section1)
# * [Data Loading](#section2)
# * [Exploratory Data Analysis](#section3)

# %% [markdown]
# <a id="data"></a>
# # **About the Data:**

# %% [markdown]
# The dataset can be found at https://archive.ics.uci.edu/dataset/519/heart+failure+clinical+records
#
# Data Description:
#
# * age: age of the patient (years)
# * anaemia: decrease of red blood cells or hemoglobin (boolean)
# * creatinine phosphokinase  (CPK): level of the CPK enzyme in the blood (mcg/L)
# * diabetes: if the patient has diabetes (boolean)
# * ejection fraction: percentage of blood leaving the heart at each contraction  (percentage)
# * high blood pressure: if the patient has hypertension (boolean)
# * platelets: platelets in the blood (kiloplatelets/mL)
# * sex: woman or man (binary)
# * serum creatinine: level of serum creatinine in the blood (mg/dL)
# * serum sodium: level of serum sodium in the blood (mEq/L)
# * smoking: if the patient smokes or not (boolean)
# * time: follow-up period (days)
# * death event: if the patient died during the follow-up period (boolean)

# %% [markdown]
# <a id='section1'></a>
# # **Import Libraries:**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <a id='section2'></a>
# # **Data Loading:**
# * Load the dataset into a pandas dataframe
#
# *  Display the first few rows of the dataset to get an overview.

# %%
data=pd.read_csv('heart_failure_clinical_records.csv')
data.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# ...

# %%
#Creating a copy of the original dataset to allow data manipulation without changes to the original dataset
df=data.copy()

# %% [markdown]
# <a id='section3'></a>
# # **Exploratory Data Analysis:**

# %% [markdown]
# <a id='overview'></a>
# # **Data Overview:**
#   - Shape of the dataset.
#   - Data types of columns. df.info()
#   - Descriptive statistics df.describe(), NB: unders

# %%
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
#Checking the shape of the dataset
print(f'The dataset has {df.shape[0]} rows and {df.shape[1]} columns')
# Out:
# The dataset has 299 rows and 13 columns

# %%
#Checking for and dropping any duplicate rows
if df.duplicated().any():
    print(f'The dataset has {df.duplicated().sum()} duplicate rows')
    df= df.drop_duplicates()
    print("Duplicate rows have been dropped.")
else:
    print("No duplicate rows found.")
# Out:
# No duplicate rows found.

# %%
#check the dataframe info, to display the columns, datatype of each column and number of values available in each cell.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
#check for any missing values in the columns
print(f'The number of missing values in each column: \n', df.isna().sum())
# Out:
# The number of missing values in each column:
#  age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %% [markdown]
# The dataset has no missing values

# %%
# Summary statistics for the numerical columns
df.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# ...

# %%
df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# ...

# %% [markdown]
# ### To allow for better interpretable visualisations the categorical attributes will be decoded appropriately:

# %%
#Decoding the 'anaemia' attribute
df['anaemia']=df['anaemia'].map({1:'Positive',0:'Negative'})

#Decoding the 'diabetes' attribute
df['diabetes'] = df['diabetes'].map({1: 'Positive', 0: 'Negative'})

#Decoding the 'high blood pressure' attribute
df['high_blood_pressure']=df['high_blood_pressure'].map({1:'Positive',0:'Negative'})

#Decoding the 'sex' attribute
df['sex']=df['sex'].map({1:'Male',0:'Female'})

#Decoding the 'smoking' attribute
df['smoking']=df['smoking'].map({1:'Smoker', 0:'Non-Smoker'})

#creating a decoded attribute from the 'Death Event' attribute
df['Death']=df['DEATH_EVENT'].map({1:"Dead",0:"Alive"})

#see how the dataset looks like after the changes.
df.head()
# Out:
#     age   anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0  Negative                       582  Negative                 20
# 1  55.0  Negative                      7861  Negative                 38
# 2  65.0  Negative                       146  Negative                 20
# 3  50.0  Positive                       111  Negative                 20
# 4  65.0  Positive                       160  Positive                 20
#
#   high_blood_pressure  platelets  serum_creatinine  serum_sodium     sex  \
# 0            Positive  265000.00               1.9           130    Male
# 1            Negative  263358.03               1.1           136    Male
# 2            Negative  162000.00               1.3           129    Male
# 3            Negative  210000.00               1.9           137    Male
# 4            Negative  327000.00               2.7           116  Female
#
#       smoking  time  DEATH_EVENT Death
# 0  Non-Smoker     4            1  Dead
# ...

# %% [markdown]
# # Questions to ask about the dataset:

# %% [markdown]
#  ## Question 1: What is the distribution of age in the dataset

# %%
#Plotting age distribution
plt.figure()
sns.histplot(df['age'], kde=True)
plt.title(f'Distribution of age')
plt.show()

print('\n')

plt.figure()
sns.boxplot(x=df['age'])
plt.title(f'Boxplot of Age')
plt.show()

# %% [markdown]
# Most of the patients in the dataset are fairly old with the youngest patient being 40 years old with a median age of 60 years, the distribution of age also seems to be symmetrical.

# %% [markdown]
# ## Question 2: What's the distribution of sex in the medical records?

# %%
sns.countplot(x=df['sex'])
plt.xlabel('Sex')
plt.ylabel('Count')
plt.title('Sex Distribution')
# Out:
# Text(0.5, 1.0, 'Sex Distribution')

# %% [markdown]
# There are more male patients than female patients in the dataset.

# %%
print(f"There are {(df[df['sex']=='Male'].shape[0])-(df[df['sex']=='Female'].shape[0])} more male than female patients in the dataset")
# Out:
# There are 89 more male than female patients in the dataset

# %% [markdown]
# ## Question 3: What's the distribution of diabetes status in the dataset?

# %%
plt.figure(figsize=(6,4))
sns.countplot(x=df['diabetes'],palette=sns.color_palette('Set3'))
plt.title('Distribution of Diabetes Status')
plt.xlabel('Diabetes')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# Most of the patients in the dataset don't have diabetes.

# %% [markdown]
# ## Question 3: What is the diabetes status between the different sexes.

# %%
sns.countplot(x='sex', hue='diabetes', data=df, palette={'Positive':"blue",'Negative':"green"} )
plt.title("Diabetes by Sex")
plt.xlabel("Sex")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# It appears that there is a higher prevalence of diabetes among female patients relative to their male counterparts.

# %% [markdown]
# ## Question 4: What's the distribution of anaemia status in the records?

# %%
#distribution of patients anaemia status
anaemia=df['anaemia'].value_counts()
plt.pie(anaemia,labels=anaemia.index,autopct='%1.1f%%')
plt.axis('equal')
plt.show()

# %% [markdown]
# There is a small difference in the number of patients with and without anemia, however the majority of patients (56.9%) do not have it.

# %% [markdown]
# ## Question 5: What's the distribution of patient high blood pressure status?

# %%
#distribution of patients anaemia status
hbp=df['high_blood_pressure'].value_counts()
plt.pie(hbp,labels=hbp.index,autopct='%1.1f%%',colors=['tomato','gold'], startangle=90)
plt.axis('equal')
plt.show()

# %% [markdown]
# The majority of patients do not have high blood pressure.

# %% [markdown]
# ## Question 6:  What's the high blood pressure status distribution between the sexes?

# %%
sns.countplot(x='sex', hue='high_blood_pressure', data=df, palette={'Positive':"c",'Negative':"m"} )
plt.title("High Blood Pressure by Sex")
plt.xlabel("Sex")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
#here we gonna do some percentage difference calculations.
df[(df['sex']=='Male') & (df['high_blood_pressure']=='Positive')].shape[0]
# Out:
# 61

# %% [markdown]
# ## Question 7: What's the smoking status distribution in the dataset?

# %%
plt.figure(figsize=(6,4))
sns.countplot(x=df['smoking'],palette=sns.color_palette('Set2'))
plt.title('Distribution of Smoking')
plt.xlabel('Smoking Status')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# There are significantly more non-smokers than smokers in the dataset.

# %% [markdown]
# ## Question 10: What's the smoking status between the sexes?

# %%
sns.countplot(x='sex', hue='smoking', data=df, palette={'Smoker':"b",'Non-Smoker':"m"} )
plt.title("Smoking Status by Sex")
plt.xlabel("Sex")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# It appears that there is a higher prevalence of smoking among males relative to females.

# %% [markdown]
# ## In this section the focus is more on the relationship between the attributes and mortality.

# %% [markdown]
# ## Question 11: What's the distribution of death status?

# %%
plt.figure(figsize=(6,4))
sns.countplot(x=df['Death'],palette=sns.color_palette('Set2'))
plt.title('Distribution of Death Status')
plt.xlabel('Death Status')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# It appears that most of the patients didn't die from heart failure before the end of the follow up period.

# %% [markdown]
# ## Question 12: Does smoking influence mortality status?

# %%
sns.countplot(x='Death', hue='smoking', data=df, palette={'Smoker':"r",'Non-Smoker':"y"} )
plt.title("Death Status vs Smoking")
plt.xlabel("Dead or Alive")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# Suprisingly the visual suggests that smoking status isn't strongly correlated with mortality from heart failure.

# %% [markdown]
# ## Question 13: What's the relationship between high_blood_pressure and death status?

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='Death', hue='high_blood_pressure', data=df, palette={'Positive':"orangered",'Negative':"deepskyblue"} )
plt.title("Relationship between Death Status and High Blood Pressure")
plt.xlabel("Death Status")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# The doesn't appear to be a strong correlation between high blood pressure status and mortality.

# %% [markdown]
# ## Question 14: What's the relation between diabetes and death status?

# %%
sns.countplot(x='Death', hue='diabetes', data=df, palette=sns.color_palette('Set2') )
plt.title("Death Status vs Diabetes")
plt.xlabel("Dead or Alive")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# There doesn't appear to be a relationship between death from heart failure and diabetes status.

# %% [markdown]
# ## Question 15: What's the relationship between follow-up time and Death Status?

# %%
plt.figure(figsize=(8,6))
sns.displot(df, x="time", hue = 'Death', kind="kde")
plt.title('Relationship between follow-up time and mortality', size=12)
plt.xlabel('Follow-up Time')
plt.show()

# %% [markdown]
# From the graph it seems that a shorter follow-up time is correlated with mortality from heart failure.

# %% [markdown]
# ## Question 16: What's the relationship between age and death status?

# %%
plt.figure(figsize=(8,6))
sns.histplot(data = df, x = "age", kde = True, hue = "Death", palette=sns.color_palette('inferno',2))
plt.title(f'Distribution of Death Status by Age')
plt.xlabel('Age')
plt.ylabel('Density')
# Out:
# Text(0, 0.5, 'Density')

# %% [markdown]
# The graph suggests a correlation between old age and mortality, indicating that older patients are more likely to die from heart failure.

# %% [markdown]
# ## Question 17: What's the relationship between ejection fraction and death status?

# %%
plt.figure(figsize=(8,6))
sns.histplot(data = df, x = "ejection_fraction", kde = True, hue = "Death")
plt.title(f'Distribution of ejection fraction')
plt.xlabel('Ejection Fraction')
plt.ylabel('Density')
plt.show()
print('\n')
plt.figure(figsize=(8,6))
sns.boxplot(data=df, x='Death', y='ejection_fraction')
plt.title('Ejection Fraction Distribution by Death Status')
# Out:
# Text(0.5, 0, 'Death Status')

# %% [markdown]
# From the visual analysis the appears to be an association between low ejection fraction and mortality.

# %% [markdown]
# ## Question 18: What's the relation between serum creatinine and death status?

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data=df, x='Death', y='serum_creatinine')
plt.xlabel('Death Status')
plt.title('Serum Creatinine Distribution by Death Status')
# Out:
# Text(0.5, 1.0, 'Serum Creatinine Distribution by Death Status')

# %% [markdown]
# From the visual analysis there appears to be an association between high serum creatinine levels and mortality.

# %% [markdown]
# ## Question 19: What's the correlation between the features?

# %%
plt.figure(figsize=(10,8))
sns.heatmap(data=data.corr(),annot=True,linewidths=2)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Question 20: What's the average age of heart disease patients?

# %%
print(f"The average age of heart disease patients is {round(df['age'].mean(),2)}years")
# Out:
# The average age of heart disease patients is 60.83years
